# %%
# %load_ext autoreload
# %autoreload 2

from football import world, universe, forecaster
import pdb
from numpy import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
uu = universe(crowd={"pmm":1, "pmp":1, "truth":1}, p_t=0.99)
wo = 512
ga = 1024
uu.play(numworlds=wo, numgames=ga)
uu.plot_rank_freq()
# Out:
# /home/molly/Documents/chaos/final/football.py:49: RuntimeWarning: divide by zero encountered in log2
#   return 25 * 1 + log2(p)

# %%
uu2 = universe(crowd={"pmm":1, "pmp":1, "truth":1}, p_t=0.55)
wo = 512
ga = 1024
uu2.play(numworlds=wo, numgames=ga)
uu2.plot_rank_freq()

# %%
uu3 = universe(crowd={'inside':3,'side':3,'pmm':3,'truth':1}, p_t=0.55)
uu3.play()
uu3.plot_rank_freq()
# Out:
# /home/molly/Documents/chaos/final/football.py:49: RuntimeWarning: invalid value encountered in log2
#   return 25 * 1 + log2(p)

# %%
uu4 = universe(crowd={'inside':3,'side':3,'pmm':3,'truth':1}, p_t=0.55)
uu4.play()
uu4.plot_rank_freq()

# %%
longer = universe(crowd={'inside':3,'side':3,'pmm':3,'truth':1}, p_t=0.55)
longer.play(numgames=1500)
longer.plot_rank_freq()

# %%
uu5 = universe(crowd={'inside':3,'side':3,'pmm':3,'truth':1}, p_t=0.55)
uu5.play(25,50)
uu5.plot_rank_freq()

# %%
with_dist = universe(crowd={'pmm':1,'pmp':1,'truth':1}, d_t=random.normal, loc=0.5, scale=0.05)
with_dist.play(50,100)
with_dist.plot_rank_freq()

# %% [markdown]
# Who's on first?

# %%
with_dist.
# Out:
#   File "/tmp/ipykernel_1080394/976068079.py", line 1
#     with_dist.
#               ^
# SyntaxError: invalid syntax
