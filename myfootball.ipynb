# %%
# %load_ext autoreload
# %autoreload 2

from football import world, universe, forecaster
import pdb
from numpy import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
uu = universe(crowd={"oversure":1, "averse":1, "truth":1}, p_t=0.7)
wo = 512
ga = 1024
uu.play(numworlds=wo, numgames=ga)
uu.plot_rank_freq()

# %%
uu2 = universe(crowd={"oversure":1, "averse":1, "truth":1}, p_t=0.8)
wo = 50
ga = 100
uu2.play(numworlds=wo, numgames=ga)
uu2.plot_rank_freq()
print(uu2.worlds[1].longdf)
# Out:
#      game  forecaster  outcomes  truth   p_        ign_  brier_  ign_rank  \
# 0       0           0         1    0.8  0.4   -8.048202    0.36       3.0
# 1       1           0         1    0.8  0.4  -16.096405    0.72       3.0
# 2       2           0         1    0.8  0.4  -24.144607    1.08       3.0
# 3       3           0         1    0.8  0.4  -32.192809    1.44       3.0
# 4       4           0         1    0.8  0.4  -40.241012    1.80       3.0
# ..    ...         ...       ...    ...  ...         ...     ...       ...
# 295    95           2         1    0.8  0.8  827.372572   13.44       1.0
# 296    96           2         1    0.8  0.8  844.324370   13.48       1.0
# 297    97           2         1    0.8  0.8  861.276168   13.52       1.0
# 298    98           2         1    0.8  0.8  878.227965   13.56       1.0
# 299    99           2         1    0.8  0.8  895.179763   13.60       1.0
#
#      brier_rank archetype
# 0           1.0  oversure
# ...

# %%
uu3 = universe(crowd={'side':1,'oversure':1,'truth':1}, p_t=0.8)
uu3.play()
uu3.plot_rank_freq()

# %%
U = uu3.worlds[5].longdf
sum(U['outcomes'])/len(U['outcomes'])
# Out:
# 0.7890625

# %%
uu4 = universe(crowd={'side':3,'oversure':3,'truth':1}, p_t=0.75)
uu4.play()
uu4.plot_rank_freq()

# %%
longer = universe(crowd={'side':3,'averse':3,'oversure':3,'truth':1}, p_t=0.55)
longer.play(numgames=1500)
longer.plot_rank_freq()

# %%
uu5 = universe(crowd={'side':3,'oversure':3,'truth':1}, p_t=0.8)
uu5.play(25,50)
uu5.plot_rank_freq()

# %%
with_dist = universe(crowd={'oversure':1,'averse':1,'truth':1}, d_t=random.normal, loc=0.5, scale=0.05)
with_dist.play(50,100)
with_dist.plot_rank_freq()

# %% [markdown]
# Who's on first?

# %%
with_dist.
# Out:
#   File "/tmp/ipykernel_139918/976068079.py", line 1
#     with_dist.
#               ^
# SyntaxError: invalid syntax
