# %%
# %load_ext autoreload
# %autoreload 2

from football import world, universe, forecaster
import pdb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
uu = universe(p_t=0.95, **{"pmm":1, "pmp":1, "truth":1})
wo = 512
ga = 1024
uu.play(numworlds=wo, numgames=ga)
uu.plot_rank_freq()

# %%
uu2 = universe(p_t=0.55, **{"pmm":1, "pmp":1, "truth":1})
wo = 512
ga = 1024
uu2.play(numworlds=wo, numgames=ga)
uu2.plot_rank_freq()

# %%
uu3 = universe(p_t=0.55, **{'inside':3,'side':3,'pmm':3,'truth':1})
uu3.play()
uu3.plot_rank_freq()

# %%
uu4 = universe(p_t=0.55, **{'inside':3,'side':3,'pmm':3,'truth':1})
uu4.play()
uu4.plot_rank_freq()
# Out:
# /home/molly/Documents/chaos/final/football.py:49: RuntimeWarning: invalid value encountered in log2
#   return 25 * 1 + log2(p)

# %%
longer = universe(p_t=0.55, **{'inside':3,'side':3,'pmm':3,'truth':1})
longer.play(numgames=1500)
longer.plot_rank_freq()

# %%
uu5 = universe(p_t=0.55, **{'inside':3,'side':3,'pmm':3,'truth':1})
uu5.play(5,10)
uu5.plot_rank_freq()
# Out:
# /home/molly/Documents/chaos/final/football.py:49: RuntimeWarning: invalid value encountered in log2
#   return 25 * 1 + log2(p)
